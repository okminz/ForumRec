# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# %%
def get_df(file):
    parsed = ET.parse(file)
    root = parsed.getroot()
    
    data = []

    for i, child in enumerate(root):
        data.append(child.attrib)
        
    dfItem = pd.DataFrame.from_records(data).set_index('Id')
    return dfItem

# %%
file_directory = '../../../../../Volumes/easystore/DataScience/superuser.com'
file = '/Posts.xml'
file_path = file_directory + file

# %%
posts = get_df(file_path)

# %%
users = get_df(file_path)

# %%
tags = get_df(file_path)

# %%
posts.head()
# Out:
#    PostTypeId AcceptedAnswerId             CreationDate Score ViewCount  \
# Id
# 1           1           727273  2009-07-15T06:27:46.723   175    114409
# 24          1              NaN  2009-07-08T16:32:47.817     7      6536
# 25          2              NaN  2009-07-08T16:34:52.867     0       NaN
# 26          2              NaN  2009-07-08T16:59:00.587     0       NaN
# 27          2              NaN  2009-07-08T17:15:59.477     1       NaN
#
#                                                  Body OwnerUserId  \
# Id
# 1   <p>A Vista virtual machine I use only has a 10...           1
# 24  <p>I used to record important technical meetin...         NaN
# 25  <p>You could use a filter on the recording. A ...        9637
# 26  <p>Try out something like Audible for Macs, an...       23242
# 27  <p>You definitely need some sort of software t...       45675
#
#    LastEditorUserId             LastEditDate         LastActivityDate  ...  \
# Id                                                                     ...
# 1                -1  2020-06-12T13:48:39.473  2018-10-22T12:24:16.070  ...
# 24            36744  2012-08-08T21:06:48.087  2020-10-19T16:12:15.757  ...
# 25          1218738  2020-10-09T16:36:16.537  2020-10-09T16:36:16.537  ...
# 26          1218738  2020-10-19T16:12:15.757  2020-10-19T16:12:15.757  ...
# 27              NaN                      NaN  2009-07-15T06:48:44.300  ...
#
#                                   Tags AnswerCount CommentCount FavoriteCount  \
# Id
# 1        <windows><disk-space><winsxs>          12           10            89
# 24  <audio><audio-recording><camtasia>           6            0             5
# 25                                 NaN         NaN            0           NaN
# 26                                 NaN         NaN            0           NaN
# 27                                 NaN         NaN            1           NaN
#
#    ContentLicense OwnerDisplayName ParentId ClosedDate CommunityOwnedDate  \
# Id
# 1    CC BY-SA 3.0              NaN      NaN        NaN                NaN
# 24   CC BY-SA 3.0       essamSALAH      NaN        NaN                NaN
# 25   CC BY-SA 4.0         Burkhard       24        NaN                NaN
# 26   CC BY-SA 4.0      Jas Panesar       24        NaN                NaN
# 27   CC BY-SA 2.5           T Pops       24        NaN                NaN
#
#    LastEditorDisplayName
# Id
# 1                    NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
#
# [5 rows x 21 columns]

# %%
relevant = posts[['PostTypeId', 'CreationDate', 'Score', 'Body', 'Tags', 'OwnerUserId', 'AnswerCount', 'ParentId']]
relevant
# Out:
#         PostTypeId             CreationDate Score  \
# Id
# 1                1  2009-07-15T06:27:46.723   175
# 24               1  2009-07-08T16:32:47.817     7
# 25               2  2009-07-08T16:34:52.867     0
# 26               2  2009-07-08T16:59:00.587     0
# 27               2  2009-07-08T17:15:59.477     1
# ...            ...                      ...   ...
# 1607673          1  2020-12-06T04:16:34.360     0
# 1607675          1  2020-12-06T04:27:04.807     0
# 1607676          2  2020-12-06T04:34:37.490     0
# 1607677          1  2020-12-06T05:11:18.143     0
# 1607678          2  2020-12-06T05:14:36.420     0
#
#                                                       Body  \
# Id
# 1        <p>A Vista virtual machine I use only has a 10...
# 24       <p>I used to record important technical meetin...
# 25       <p>You could use a filter on the recording. A ...
# 26       <p>Try out something like Audible for Macs, an...
# 27       <p>You definitely need some sort of software t...
# ...                                                    ...
# 1607673  <p>I have always created Virtual Machines on m...
# 1607675  <p><strong>=VLOOKUP(VLOOKUP(A7,InventoryLog,5,...
# 1607676  <p>If you have Python 3 installed, you could u...
# 1607677  <p>I have a problem which I cannot figure out....
# 1607678  <p>Apparently Above 4G decoding <a href="https...
#
#                                                       Tags OwnerUserId  \
# Id
# 1                            <windows><disk-space><winsxs>           1
# 24                      <audio><audio-recording><camtasia>         NaN
# 25                                                     NaN        9637
# 26                                                     NaN       23242
# 27                                                     NaN       45675
# ...                                                    ...         ...
# 1607673  <windows><virtualbox><virtual-machine><azure><...      475817
# 1607675              <microsoft-excel><worksheet-function>     1248251
# 1607676                                                NaN      470014
# 1607677  <windows-10><networking><wifi-configuration><i...      722192
# 1607678                                                NaN     1010837
#
#         AnswerCount ParentId
# Id
# 1                12      NaN
# 24                6      NaN
# 25              NaN       24
# 26              NaN       24
# 27              NaN       24
# ...             ...      ...
# 1607673           0      NaN
# 1607675           0      NaN
# 1607676         NaN  1315365
# 1607677           0      NaN
# 1607678         NaN  1239231
#
# [1113829 rows x 8 columns]

# %%
questions = relevant[relevant['PostTypeId'] == '1'].drop(['PostTypeId', 'ParentId'], axis=1)
answers = relevant[relevant['PostTypeId'] == '2'].drop(['PostTypeId', 'AnswerCount', 'Tags'], axis=1)

# %%
# Questions only
questions
# Out:
#                     CreationDate Score  \
# Id
# 1        2009-07-15T06:27:46.723   175
# 24       2009-07-08T16:32:47.817     7
# 29       2009-07-15T07:11:46.370    23
# 37       2009-07-15T07:17:13.970     4
# 46       2009-07-15T07:20:00.717    16
# ...                          ...   ...
# 1607669  2020-12-06T03:17:52.090     0
# 1607671  2020-12-06T03:59:14.313     0
# 1607673  2020-12-06T04:16:34.360     0
# 1607675  2020-12-06T04:27:04.807     0
# 1607677  2020-12-06T05:11:18.143     0
#
#                                                       Body  \
# Id
# 1        <p>A Vista virtual machine I use only has a 10...
# 24       <p>I used to record important technical meetin...
# 29       <p>What is the difference between the two supe...
# 37       <p>My late 2008, Macbook Pro Unibody machine h...
# 46       <p>Is there any way to configure application t...
# ...                                                    ...
# 1607669  <p>I'm trying to get the &quot;Facebook Page U...
# 1607671  <p>When I start for Windows settings, such as ...
# 1607673  <p>I have always created Virtual Machines on m...
# 1607675  <p><strong>=VLOOKUP(VLOOKUP(A7,InventoryLog,5,...
# 1607677  <p>I have a problem which I cannot figure out....
#
#                                                       Tags OwnerUserId  \
# Id
# 1                            <windows><disk-space><winsxs>           1
# 24                      <audio><audio-recording><camtasia>         NaN
# 29                                     <linux><unix><sudo>          13
# 37                                 <mac><crash><boot-camp>          26
# 46          <windows><boot><windows-vista><uac><elevation>          21
# ...                                                    ...         ...
# 1607669                         <facebook><advertisements>      930695
# 1607671           <windows-10><start-menu><windows-search>     1017832
# 1607673  <windows><virtualbox><virtual-machine><azure><...      475817
# 1607675              <microsoft-excel><worksheet-function>     1248251
# 1607677  <windows-10><networking><wifi-configuration><i...      722192
#
#         AnswerCount
# Id
# 1                12
# 24                6
# 29                9
# 37                3
# 46                2
# ...             ...
# 1607669           0
# 1607671           0
# 1607673           0
# 1607675           0
# 1607677           0
#
# [453382 rows x 6 columns]

# %%
# Answers only
answers
# Out:
#                     CreationDate Score  \
# Id
# 25       2009-07-08T16:34:52.867     0
# 26       2009-07-08T16:59:00.587     0
# 27       2009-07-08T17:15:59.477     1
# 34       2009-07-15T07:16:12.363     9
# 38       2009-07-15T07:17:21.910     1
# ...                          ...   ...
# 1607668  2020-12-06T02:59:58.460     0
# 1607670  2020-12-06T03:17:54.600     0
# 1607672  2020-12-06T04:10:54.117     0
# 1607676  2020-12-06T04:34:37.490     0
# 1607678  2020-12-06T05:14:36.420     0
#
#                                                       Body OwnerUserId  \
# Id
# 25       <p>You could use a filter on the recording. A ...        9637
# 26       <p>Try out something like Audible for Macs, an...       23242
# 27       <p>You definitely need some sort of software t...       45675
# 34       <p><a href="http://audacity.sourceforge.net/" ...          17
# 38       <p>On systems where the superuser account is d...          55
# ...                                                    ...         ...
# 1607668  <p>These are collapsible styles, you will not ...     1248233
# 1607670  <p>As <a href="https://superuser.com/users/432...      278403
# 1607672  <p>I've been searching and the problem is &quo...     1240079
# 1607676  <p>If you have Python 3 installed, you could u...      470014
# 1607678  <p>Apparently Above 4G decoding <a href="https...     1010837
#
#         ParentId
# Id
# 25            24
# 26            24
# 27            24
# 34            24
# 38            29
# ...          ...
# 1607668  1604060
# 1607670  1607663
# 1607672  1601514
# 1607676  1315365
# 1607678  1239231
#
# [652990 rows x 5 columns]

# %%
# users, don't rerun
users = users.drop_duplicates(subset=['AccountId']).reset_index().set_index('AccountId')

# %%
users
# Out:
#                 Id Reputation             CreationDate       DisplayName  \
# AccountId
# -1              -1          1  2009-07-12T22:51:42.563         Community
# 1                1      22674  2009-07-12T22:51:42.563       Jeff Atwood
# 2                2        363  2009-07-12T22:51:42.563      Geoff Dalgas
# 3                3        101  2009-07-12T22:51:42.563      Jarrod Dixon
# 4                4       1774  2009-07-12T22:51:42.563      Joel Spolsky
# ...            ...        ...                      ...               ...
# 7571261    1248254          1  2020-12-06T04:40:59.623       user5745279
# 20143310   1248255          1  2020-12-06T04:56:51.923   aussietheatre71
# 20143320   1248256          1  2020-12-06T04:59:35.167      Scooba Dooba
# 20143339   1248257          1  2020-12-06T05:04:07.383       user1248257
# 20143351   1248258          1  2020-12-06T05:07:36.170  saniah akuntansi
#
#                     LastAccessDate                         WebsiteUrl  \
# AccountId
# -1         2008-07-31T00:00:00.000     http://meta.stackexchange.com/
# 1          2020-12-03T19:13:49.677  http://www.codinghorror.com/blog/
# 2          2020-11-30T21:21:33.480           http://stackoverflow.com
# 3          2020-11-18T18:24:15.340             http://jarroddixon.com
# 4          2020-10-28T20:04:59.157        https://joelonsoftware.com/
# ...                            ...                                ...
# 7571261    2020-12-06T04:40:59.623                                NaN
# 20143310   2020-12-06T04:56:51.923     http://db.aussietheatre.com.au
# 20143320   2020-12-06T04:59:35.167                                NaN
# 20143339   2020-12-06T05:04:07.383                                NaN
# 20143351   2020-12-06T05:07:36.170                                NaN
#
#                              Location  \
# AccountId
# -1                 on the server farm
# 1                      El Cerrito, CA
# 2                       Corvallis, OR
# 3          Raleigh, NC, United States
# 4                        New York, NY
# ...                               ...
# 7571261                           NaN
# 20143310                          NaN
# 20143320                          NaN
# 20143339                          NaN
# 20143351                          NaN
#
#                                                      AboutMe  Views UpVotes  \
# AccountId
# -1         <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...     79   53210
# 1          <p><a href="http://www.codinghorror.com/blog/a...  60396    1706
# 2          <p>Developer on the Stack Overflow team.  Find...    337      47
# 3          <p><a href="http://blog.stackoverflow.com/2009...    235     533
# 4          <p>In 2000 I co-founded Fog Creek Software, wh...   1115      81
# ...                                                      ...    ...     ...
# 7571261                                                  NaN      0       0
# 20143310   <p>in our website you can find <a href="http:/...      0       0
# 20143320                                                 NaN      0       0
# 20143339                                                 NaN      0       0
# 20143351                                                 NaN      0       0
#
#           DownVotes                                    ProfileImageUrl
# AccountId
# -1           168298                                                NaN
# 1                64                                                NaN
# 2                 1                https://i.stack.imgur.com/nDllk.png
# 3                 0                                                NaN
# 4                 8      https://i.stack.imgur.com/C5gBG.jpg?s=128&g=1
# ...             ...                                                ...
# 7571261           0  https://www.gravatar.com/avatar/5e42ec9baa5bb0...
# 20143310          0  https://www.gravatar.com/avatar/029938f592e3c8...
# 20143320          0  https://lh5.googleusercontent.com/-AVVAs47x6q0...
# 20143339          0  https://www.gravatar.com/avatar/0e6bb707a37d1b...
# 20143351          0  https://lh3.googleusercontent.com/a-/AOh14Ghdf...
#
# [957889 rows x 12 columns]

# %%
score = users[['UpVotes', 'DownVotes', 'Reputation', 'Views']].astype(int)
score.describe()
# Out:
#              UpVotes      DownVotes     Reputation          Views
# count  957889.000000  957889.000000  957889.000000  957889.000000
# mean        3.454732       0.510287      61.691174       6.256935
# std        76.751208     181.633768     791.094495     168.099552
# min         0.000000       0.000000       1.000000       0.000000
# 25%         0.000000       0.000000       1.000000       0.000000
# 50%         0.000000       0.000000       1.000000       0.000000
# 75%         0.000000       0.000000     101.000000       2.000000
# max     53210.000000  168298.000000  338633.000000   63301.000000

# %%
score
# Out:
#            UpVotes  DownVotes  Reputation  Views
# AccountId
# -1           53210     168298           1     79
# 1             1706         64       22674  60396
# 2               47          1         363    337
# 3              533          0         101    235
# 4               81          8        1774   1115
# ...            ...        ...         ...    ...
# 7571261          0          0           1      0
# 20143310         0          0           1      0
# 20143320         0          0           1      0
# 20143339         0          0           1      0
# 20143351         0          0           1      0
#
# [957889 rows x 4 columns]

# %% [markdown]
# Because the up votes and down votes are heavily skew to the top users compared to reputation, it is hard ot determine if to use up votes and down votes are to use reputation, however, we also see that the reputation value is not necessarily related to up votes and down votes and may include views, which may not necessarily mean they are better question answerers. We will likely use either up votes and down votes as a metric of the ability of the user, or use reputation, however, we know we have this data for users, and the most relevant users, those who answer questions likely have this data as well that we can use to help build reviews or identify cold start problems (Where users have no votes or reputation) that we can use a different recommendation system weight to address.

# %%
score.UpVotes.value_counts()
# Out:
# 0       776650
# 1        44215
# 2        27073
# 3        16409
# 4        12132
#          ...
# 854          1
# 1685         1
# 662          1
# 2198         1
# 740          1
# Name: UpVotes, Length: 968, dtype: int64

# %%
users.reset_index().set_index('AccountId').loc[users['AccountId'].value_counts()[users['AccountId'].value_counts() > 1].index.tolist()]
# Out:
#                 Id Reputation             CreationDate  \
# AccountId
# 13532404   1037001         21  2019-05-16T08:17:58.683
# 13532404   1054370          1  2019-06-25T07:08:40.287
# 16987074   1114436          1  2019-11-20T16:32:04.150
# 16987074   1114450          1  2019-11-20T17:10:54.867
# 115519       94996        101  2011-08-21T10:47:53.257
# 115519      185284        101  2013-01-08T09:04:10.107
# 8813383     616858         33  2016-07-13T17:12:16.010
# 8813383     691141          1  2017-01-28T17:08:18.260
# 14613601   1040937         11  2019-05-24T20:25:15.727
# 14613601   1041361          1  2019-05-26T05:51:52.560
# 18645624   1240433          1  2020-11-13T10:06:21.627
# 18645624   1240434          1  2020-11-13T10:06:41.377
# 418783      759189        111  2017-08-08T08:49:02.040
# 418783      759193        101  2017-08-08T09:08:11.273
#
#                                     DisplayName           LastAccessDate  \
# AccountId
# 13532404                            Gil Brudner  2020-12-02T08:26:32.703
# 13532404                                RoboGil  2019-06-25T07:08:40.287
# 16987074                                Brandon  2019-11-20T16:32:04.150
# 16987074   a25bedc5-3d09-41b8-82fb-ea6c353d75ae  2019-11-20T17:10:54.867
# 115519                         Chamika Sandamal  2020-10-28T11:07:09.727
# 115519                         Chamika Sandamal  2015-04-02T15:42:31.373
# 8813383                              Aimsworthy  2020-04-21T17:10:24.077
# 8813383                              Aimsworthy  2017-01-28T17:08:18.260
# 14613601                                  alokp  2019-05-26T06:44:09.763
# 14613601                              Alok Pota  2019-05-26T05:51:52.560
# 18645624                                  Terry  2020-12-04T15:50:33.620
# 18645624                                  Terry  2020-11-13T10:06:41.377
# 418783                       Jignesh Ansodariya  2018-08-27T04:59:55.873
# 418783     a25bedc5-3d09-41b8-82fb-ea6c353d75ae  2017-08-08T09:08:11.273
#
#                                    WebsiteUrl                 Location  \
# AccountId
# 13532404                                  NaN                      NaN
# 13532404                                  NaN                   Israel
# 16987074                                  NaN                      NaN
# 16987074                                  NaN                      NaN
# 115519      http://cmsnsoftware.blogspot.com/                Sri Lanka
# 115519     http://tutorials.cmsnsoftware.com/                Sri Lanka
# 8813383                                        Colorado, United States
# 8813383                                   NaN                      NaN
# 14613601                                  NaN                      NaN
# 14613601                                  NaN                      NaN
# 18645624                                  NaN                      NaN
# 18645624                                  NaN                      NaN
# 418783                                    NaN                Ahmedabad
# 418783                                    NaN                      NaN
#
#                                                      AboutMe Views UpVotes  \
# AccountId
# 13532404                                                 NaN     7       0
# 13532404                                                 NaN     0       0
# 16987074                                                 NaN     0       0
# 16987074                                                 NaN     0       0
# 115519     <p><a href="http://cmsnsoftware.blogspot.com/"...     5       0
# 115519     <h1>SOreadytohelp</h1>\n\n<p><img src="https:/...     4       1
# 8813383                                                         14       0
# 8813383                                                  NaN     1       0
# 14613601                                                 NaN     8       0
# 14613601                                                 NaN     0       0
# 18645624                                                 NaN     0       0
# 18645624                                                 NaN     0       0
# 418783     <p>Ansodariya Jignesh J.\nAndroid Developer.</...     1       0
# 418783                                                   NaN     0       0
#
#           DownVotes                                    ProfileImageUrl
# AccountId
# 13532404          0                                                NaN
# 13532404          0  https://lh4.googleusercontent.com/-4W2vAx7TpgQ...
# 16987074          0  https://www.gravatar.com/avatar/17ee0503dfd5a0...
# 16987074          0  https://www.gravatar.com/avatar/17ee0503dfd5a0...
# 115519            0                                                NaN
# 115519            0                                                NaN
# 8813383           0                                                NaN
# 8813383           0  https://www.gravatar.com/avatar/de77a540ab8a82...
# 14613601          0                                                NaN
# 14613601          0  https://lh5.googleusercontent.com/-3l6zFY6tfNo...
# 18645624          0  https://www.gravatar.com/avatar/5daa6c938d7ab3...
# 18645624          0  https://www.gravatar.com/avatar/5daa6c938d7ab3...
# 418783            0      https://i.stack.imgur.com/yWK9F.jpg?s=128&g=1
# 418783            0  https://www.gravatar.com/avatar/116316761fa5a4...

# %%
tags
# Out:
#           TagName  Count ExcerptPostId WikiPostId
# Id
# 203      firmware    425        392824     392823
# 204       upgrade   1183        320795     320794
# 205    networking  29881        244736     244735
# 206         audio   6416        257013     257012
# 207         video   5289        256215     256214
# ...           ...    ...           ...        ...
# 20479        gitk      1           NaN        NaN
# 20480  finereader      1           NaN        NaN
# 20481       apipa      1       1606069    1606068
# 20484   xencenter      1           NaN        NaN
# 20485  google-one      1           NaN        NaN
#
# [5560 rows x 4 columns]

# %%
#tags
tags['Count'] = tags['Count'].astype(int)
tag_count = tags[['TagName', 'Count']]
tag_count[tag_count['Count'] > 1].sort_values('Count', ascending=False).shape[0]
print('Total number of tags: ' + str(tag_count.shape[0]))
print('Tags with more than 1 appearance: ' + str(tag_count[tag_count['Count'] > 1].sort_values('Count', ascending=False).shape[0]))
print('Tags with more than 10 appearance: ' + str(tag_count[tag_count['Count'] > 10].sort_values('Count', ascending=False).shape[0]))
print('Tags with more than 50 appearance: ' + str(tag_count[tag_count['Count'] > 50].sort_values('Count', ascending=False).shape[0]))
print('Tags with more than 100 appearance: ' + str(tag_count[tag_count['Count'] > 100].sort_values('Count', ascending=False).shape[0]))
print('Tags with more than 500 appearance: ' + str(tag_count[tag_count['Count'] > 500].sort_values('Count', ascending=False).shape[0]))
# Out:
# Total number of tags: 5560
# Tags with more than 1 appearance: 5390
# Tags with more than 10 appearance: 4031
# Tags with more than 50 appearance: 2088
# Tags with more than 100 appearance: 1380
# Tags with more than 500 appearance: 414

# %% [markdown]
# We can definitely use tags, as there are many tags that appear in the SuperUser database, and many of them that appear a couple of times, and a large amount that appear many times throughout the posts that have appeared on the forum. We can use this tag data to be able to associate different posts with one another and determine users who are best to handle posts of a certain type of category to be able to make better recommendations.

# %% [markdown]
# # Validation and Test Data

# %% [markdown]
# ### Use only needed data and convert to right format

# %%
relevant = posts[['PostTypeId', 'CreationDate', 'Score', 'Body', 'Tags', 'OwnerUserId', 'AnswerCount', 'ParentId']]
questions = relevant[relevant['PostTypeId'] == '1'].drop(['PostTypeId', 'ParentId'], axis=1)
answers = relevant[relevant['PostTypeId'] == '2'].drop(['PostTypeId', 'AnswerCount', 'Tags'], axis=1)

# %%
relevant['CreationDate'] = pd.to_datetime(relevant['CreationDate'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
answered_data = relevant[relevant['AnswerCount'] != '0']

# %% [markdown]
# ###  Split into training and evaluating data

# %%
train_data = answered_data[answered_data['CreationDate'] < pd.datetime(2019, 9, 1)]
evaluation_data = answered_data[answered_data['CreationDate'] >= pd.datetime(2019, 9, 1)]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %% [markdown]
# ### Get questions from evaluation data and split in half for validation and testing

# %%
question_ids = np.array(evaluation_data[evaluation_data['PostTypeId'] == '1'].index)
np.random.shuffle(question_ids)
valid_questions_index = question_ids[:question_ids.size//2]
test_questions_index = question_ids[question_ids.size//2:]

# %% [markdown]
# ### Split validation and test datasets into questions and the answers to those questions

# %%
valid_questions = evaluation_data.loc[valid_questions_index]
valid_answers = evaluation_data[evaluation_data['ParentId'].isin(valid_questions_index)]

# %%
test_questions = evaluation_data.loc[test_questions_index]
test_answers = evaluation_data[evaluation_data['ParentId'].isin(test_questions_index)]

# %% [markdown]
# ### Split training data, and clean up training, validation, and testing datasets

# %%
train_q = train_data[train_data['PostTypeId'] == '1'].drop(['PostTypeId', 'ParentId', 'AnswerCount'], axis=1)
train_a = train_data[train_data['PostTypeId'] == '2'].drop(['PostTypeId', 'AnswerCount', 'Tags'], axis=1)

# %%
valid_q  = valid_questions.drop(['CreationDate', 'PostTypeId', 'ParentId', 'AnswerCount'], axis=1)
valid_a = valid_answers.drop(['CreationDate', 'PostTypeId', 'AnswerCount', 'Tags'], axis=1)

# %%
test_q = test_questions.drop(['CreationDate', 'PostTypeId', 'ParentId', 'AnswerCount'], axis=1)
test_a = test_answers.drop(['CreationDate', 'PostTypeId', 'AnswerCount', 'Tags'], axis=1)

# %%
train_q
train_a
# Out:
#                    CreationDate Score  \
# Id
# 25      2009-07-08 16:34:52.867     0
# 26      2009-07-08 16:59:00.587     0
# 27      2009-07-08 17:15:59.477     1
# 34      2009-07-15 07:16:12.363     9
# 38      2009-07-15 07:17:21.910     1
# ...                         ...   ...
# 1477618 2019-08-31 22:26:15.427     0
# 1477619 2019-08-31 22:35:02.473     1
# 1477623 2019-08-31 23:08:20.670     0
# 1477624 2019-08-31 23:48:20.833     3
# 1478456 2019-08-30 17:37:46.460     4
#
#                                                       Body OwnerUserId  \
# Id
# 25       <p>You could use a filter on the recording. A ...        9637
# 26       <p>Try out something like Audible for Macs, an...       23242
# 27       <p>You definitely need some sort of software t...       45675
# 34       <p><a href="http://audacity.sourceforge.net/" ...          17
# 38       <p>On systems where the superuser account is d...          55
# ...                                                    ...         ...
# 1477618  <p>This may seem sloppy, but you can force the...     1083292
# 1477619  <p>If you do <code>man resolv.conf</code>, you...      678518
# 1477623  <p>There are several things you can try:</p>\n...         NaN
# 1477624  <p>Both Excel Online and Excel Desktop have th...         NaN
# 1478456  <p>The <em>jitter</em> command in R usually ta...         NaN
#
#         ParentId
# Id
# 25            24
# 26            24
# 27            24
# 34            24
# 38            29
# ...          ...
# 1477618  1195310
# 1477619  1475425
# 1477623  1477435
# 1477624  1477620
# 1478456  1478455
#
# [606450 rows x 5 columns]

# %%
valid_q
valid_a
# Out:
#         Score                                               Body OwnerUserId  \
# Id
# 1477636    -1  <p><em>Am I correct that Windows update bug is...     1079976
# 1477639     0  <p>I think I have myself solved my problem try...     1083302
# 1477667     1  <p>With the amount in A1 try,</p>\n\n<pre><cod...         NaN
# 1477713     1  <h3>Let's assume that there is no caching invo...      337631
# 1477717     2  <p>It looks like a key lock to me. You need th...      347380
# ...       ...                                                ...         ...
# 1607638     2  <p>From the man page for <code>ssh_config</cod...      333086
# 1607654     0  <blockquote>\n<p>I'm wondering if this will af...      239311
# 1607664     1  <p>A Wi-Fi extender that surprisingly solved t...     1247372
# 1607670     0  <p>As <a href="https://superuser.com/users/432...      278403
# 1607672     0  <p>I've been searching and the problem is &quo...     1240079
#
#         ParentId
# Id
# 1477636  1477634
# 1477639  1477630
# 1477667  1477664
# 1477713  1477710
# 1477717  1477706
# ...          ...
# 1607638  1607598
# 1607654  1607367
# 1607664  1607488
# 1607670  1607663
# 1607672  1601514
#
# [16369 rows x 4 columns]

# %%
test_q
test_a
# Out:
#         Score                                               Body OwnerUserId  \
# Id
# 1477626    -2  <p>It depends on the actual version of Windows...     1079976
# 1477657     0  <p>As the article you linked points out, the <...        7778
# 1477669    14  <p>The <code>/IM</code> parameter for taskkill...      917605
# 1477670     5  <p>Create a batch file and use the command Tas...     1067863
# 1477685     0  <p><a href="https://wikidevi.com/wiki/Intel_Du...      567466
# ...       ...                                                ...         ...
# 1607655     0  <p>The boot problem is because drive ID's are ...     1248211
# 1607656     0  <p>When you try to run <code>rm *.bar</code> a...      432690
# 1607659     0  <p>Your <code>awk</code> command properly keep...      432690
# 1607665     0  <p>A few weeks later, I found a <a href="https...      106758
# 1607668     0  <p>These are collapsible styles, you will not ...     1248233
#
#         ParentId
# Id
# 1477626  1477625
# 1477657  1477646
# 1477669  1477654
# 1477670  1477654
# 1477685  1477679
# ...          ...
# 1607655  1533130
# 1607656  1607629
# 1607659  1607637
# 1607665  1602502
# 1607668  1604060
#
# [16324 rows x 4 columns]
